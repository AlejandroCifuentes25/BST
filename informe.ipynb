# %% [markdown]
# Autores: Julian Jimenez y alejandro Cifuentes
#
#
# Para realización de los ejercicios dispensamos del uso de la inteligencia artificial, para poder resolver dudas acerca de los ejercicios propuestos.
#
#  Ademas de videos explicativos que ayudaron a la realización, links:
#
#  https://www.youtube.com/watch?v=4bsitP3vCKA
# https://www.youtube.com/watch?v=JcsuPja5j_4
#  https://www.youtube.com/watch?v=_z6dDLeRPMg
#
# **ejercicio 1:**
#
# IDE utilizada: CLION 2025 1.3
#
# Bibliotecas utilizadas:
# include <iostream>: Permite entrada y salida estándar en C++.
#
# include <vector>: es un arreglo dinámico seguro que ayuda a hacer las matrices
# necesarias.
#
# include <cstdlib>: genera números aleatorios y semillas
#
# include <ctime>: Da la hora actual.
#
# include <chrono>: mide los tiempos.
#
# include <iomanip>: Herramientas de formato de salida.
#
# include <algorithm>: ayuda a calcular la mediana.
#
#
# Este proyecto compara tres formas de multiplicación de matrices cuadradas en row-major.
# Se utilizan matrices llenas con enteros aleatorios del 0 al 9 y se miden los tiempos para diferentes tamaños de matrices.
#
# ---
#
# Algoritmos implementados
#
# Clásica
#
# Usa triple ciclo básico con orden i–j–k:
# -Recorre cada fila de A (índice i).
# -Para esa fila, recorre cada columna de B (índice j).
# -Calcula la multiplicacion sumando A[i,k] * B[k,j].
# no es tan eficiente por que no aprovecha la memoria de la misma forma que otros algoritmos
#
#
#
# Optimizada por layout (ikj)Orden de ciclos i–k–j:
#
# Se aprovecha mejor el acceso contiguo en memoria:
# B[k,*] y C[i,*] se recorren linealmente.
# Menos fallos de caché.
# Suele ser significativamente más rápida que ijk, aunque depende del caso.
#
# Por bloques
# Divide las matrices en bloques BS × BS:
#
# Reutiliza subfilas y subcolumnas en caché.
# Mejora aún más la localidad de datos.
# En este caso se usa un bloque por defecto BS = 64.
#
# ---
#
#
#
#
#
#
#
#
# caso de prueba:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# **ejercicio 2:**
#
# IDE utilizada: CLION 2025 1.3
#
# Bibliotecas utilizadas: vector
#
# **Explicación de resultados:**
#
# Los resultados fueron acordes con las tematicas vistas en la clase, dependiendo del arbol en cuestion y con su respectivo orden se pueden ver claras diferencias en las estructuras finales de estos, en donde las listas desorganizadas fueron de menor altura y con un coste promedio de O(log(n)), el cual es un coste barato y eficiente para la programación, sus alturas reducidas debido a que se encuentran con valores menores y mayores, los cuales favorecen a la ramificación con dos hijos o un grado maximo de 2, en cambio, las listas organizadas tienden a tener una mayor altura, menos hijos o con un grado maximo de 1, asi con un coste promedio de O(n), que comparado con las listas aleatorias, es de una indola cara.
#
# Dejando asi la comparación clara del coste entre ambas listas.
#
# **Análisis crítico:**
#
# Se puede analizar que la eficiencia de un arbol binario de busqueda(BST) depende exclusivamente de la forma en la que se inserten los valores, donde las listas con valores aleatorios o balanceadas producen arboles que son mas eficientes y que en cambios listas con valores organizados requieren mayor eficiencia y por lo tanto generan un mayor costo y complejidad. Por el lado de los recorridos, estos ayudando ampliamente a saber la estructura interna de los arboles, los cuales son utiles para realizar operaciones varias, ademas de poder saber su profundidad, que referente a eso, la altura nos remarca la eficiencia de los arboles, donde con una altura menor genera mayor eficiencia y por el contrario, genera una menor eficiencia, concluyendo que la altura es directamente proporcional al coste en el peor caso. Para añadir, una de las facilidades de estos arboles con su invariante, es la busqueda de un valor, pues gracias a sus ramificaciones facilmente se puede ahorrar la mitad de un camino con el simple hecho de comparar si el valor es mayor o menor que la raiz principal.
#
# **casos de prueba:**
#
# **lista aleatoria, recorridos, altura, grado maximo:**
#
# ![image.png](data:image/png;base64,...)
#
# **lista organizada, recorridos, altura, grado maximo:**
#
# ![image.png](data:image/png;base64,...)
#
# **lista aleatoria con valores duplicados:**
#
# ![image.png](data:image/png;base64,...)
#
# **Lista aleatoria con mas de dos valores duplicados:**
#
# ![image.png](data:image/png;base64,...)
#
# **busqueda de un valor en la lista:**
#
# ![image.png](data:image/png;base64,...)
#
# **Busqueda en lista organizada: **
#
# ![image.png](data:image/png;base64,...)
#
# **busqueda sin exito en lista aleatoria**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# **busqueda sin exito en lista organizada**
#
# ![image.png](data:image/png;base64,...)
